# %% [markdown]
# # My Jupyter Notebook Notebook on IBM Watson Sdutio

# %% [markdown]
# **Vincent Mancois**
#
# Research fellow

# %% [markdown]
# *I am interested in data science because it looks fun and it is popular.*

# %% [markdown]
# ### The code below is importing numpy and playing with types

# %%
import numpy as np

x = np.array(5).astype(float)
y = np.array(5)
z = np.array(5).astype(str)

print(f"x = {x} and is of type {x.dtype}, \n"
      f"y = {y} and is of type {y.dtype}, \n"
      f"z = {z} and is of type {z.dtype}. ")

# %% [markdown]
# <div>
# <img src="https://www.paintingmania.com/arts/albert-bierstadt/large/estes-park-colorado-1869-221_33825.jpg?version=14.12.09" width=500 />
# </div>
#
# > This is a painting from ~~Pablo Picasso~~ Albert Bierstadt
# >> If you like you can find more on [google](https://www.google.com/).
